# %%
import pandas as pd
data=pd.read_csv('팀타자 끗.csv',encoding='cp949')

# %%
cols=['G_ID','G_DAY_DS','T_ID','VS_T_ID','HEADER_NO','TB_SC','PA','AB','RBI','RUN','HIT','H2',
     'H3','HR','SB','CS','SH','SF','BB','IB','HP','KK','GD','ERR','LOB','P_HRA_RT','P_AB_CN','P_HIT_CN']

# %%
data.columns
# Out:
# Index(['날짜', '팀명', '경기', '타석', '타수', '안타', '단타', '2루타', '3루타', '홈런', '득점',
#        '타점', '볼넷', '고4', 'HBP', '삼진', '희플', '희타', '병살', '도루', '도실', '타율', '초말',
#        '상대팀', '실책', '잔루', '득점권타수', '득점권안타', '득점권타율'],
#       dtype='object')

# %%
def change(data):
    
    df=pd.DataFrame()
    df['G_DAY_DS']=data['날짜']
    df['T_ID']=data['팀명']
    df['VS_T_ID']=data['상대팀']
    df['HEADER_NO']=0
    df['TB_SC']=data['초말']
    df['PA']=data['타석']
    df['AB']=data['타수']
    df['RBI']=data['타점']
    df['RUN']=data['득점']
    df['HIT']=data['안타']
    df['H2']=data['2루타']
    df['H3']=data['3루타']
    df['HR']=data['홈런']
    df['SB']=data['도루']
    df['CS']=data['도실']
    df['SH']=data['희타']
    df['SF']=data['희플']
    df['BB']=data['볼넷']
    df['IB']=data['고4']
    df['HP']=data['HBP']
    df['KK']=data['삼진']
    df['GD']=data['병살']
    df['ERR']=data['병살']
    df['LOB']=data['잔루']
    df['P_HRA_RT']=data['득점권타율']
    df['P_AB_CN']=data['득점권타수']
    df['P_HIT_CN']=data['득점권안타']
    
    return df

# %%
df=change(data)

# %%
df
# Out:
#        G_DAY_DS  T_ID VS_T_ID  HEADER_NO TB_SC  PA  AB  RBI  RUN  HIT  ...  \
# 0    2020-07-21   KIA      한화          0     T  50  41    9   10   16  ...
# 1    2020-07-21    SK      롯데          0     B  40  34    8    8   13  ...
# 2    2020-07-21    KT      LG          0     B  39  34   10   10   12  ...
# 3    2020-07-21    NC      삼성          0     B  42  38    6    6   13  ...
# 4    2020-07-21    두산      키움          0     B  32  31    6    6    7  ...
# ..          ...   ...     ...        ...   ...  ..  ..  ...  ...  ...  ...
# 454  2020-09-20    두산      LG          0     B  45  31    6    6    9  ...
# 455  2020-09-20  Hero      삼성          0     T  41  37    6    6   13  ...
# 456  2020-09-20   KIA      한화          0     B  38  33    3    3    9  ...
# 457  2020-09-20    LG      두산          0     T  38  37    5    5   10  ...
# 458  2020-09-20    SK      KT          0     B  31  28    1    2    3  ...
#
#      BB  IB  HP  KK  GD  ERR  LOB  P_HRA_RT  P_AB_CN  P_HIT_CN
# ...

# %%
df
# Out:
#        G_DAY_DS  T_ID VS_T_ID  HEADER_NO TB_SC  PA  AB  RBI  RUN  HIT  ...  \
# 0    2020-07-21   KIA      한화          0     T  50  41    9   10   16  ...
# 1    2020-07-21    SK      롯데          0     B  40  34    8    8   13  ...
# 2    2020-07-21    KT      LG          0     B  39  34   10   10   12  ...
# 3    2020-07-21    NC      삼성          0     B  42  38    6    6   13  ...
# 4    2020-07-21    두산      키움          0     B  32  31    6    6    7  ...
# ..          ...   ...     ...        ...   ...  ..  ..  ...  ...  ...  ...
# 454  2020-09-20    두산      LG          0     B  45  31    6    6    9  ...
# 455  2020-09-20  Hero      삼성          0     T  41  37    6    6   13  ...
# 456  2020-09-20   KIA      한화          0     B  38  33    3    3    9  ...
# 457  2020-09-20    LG      두산          0     T  38  37    5    5   10  ...
# 458  2020-09-20    SK      KT          0     B  31  28    1    2    3  ...
#
#      BB  IB  HP  KK  GD  ERR  LOB  P_HRA_RT  P_AB_CN  P_HIT_CN
# ...

# %%
H=pd.read_csv('더블헤더.csv',encoding='UTF-8')

# %%
DH=change(H).fillna(0)

# %%
DH['HEADER_NO']=1

# %%
DH
# Out:
#       G_DAY_DS T_ID VS_T_ID  HEADER_NO TB_SC  PA  AB  RBI  RUN  HIT  ...  BB  \
# 0   2020-08-30   KT     KIA          1     T  41  37    4    5   10  ...   3
# 1   2020-08-30  KIA      KT          1     B  38  34    7    7   10  ...   4
# 2   2020-08-30   KT     KIA          1     T  46  34    8    8    7  ...  11
# 3   2020-08-30  KIA      KT          1     B  40  33    5    5   10  ...   3
# 4   2020-09-04   SK      KT          1     T  36  34    5    5   10  ...   0
# 5   2020-09-04   KT      SK          1     B  43  33    7    7    9  ...   9
# 6   2020-09-04   SK      KT          1     T  35  32    2    2    5  ...   2
# 7   2020-09-04   KT      SK          1     B  38  35    9   10   13  ...   3
# 8   2020-09-04  KIA      롯데          1     T  40  37    7    7   10  ...   3
# 9   2020-09-04   롯데     KIA          1     B  38  34    7    9   14  ...   2
# 10  2020-09-04  KIA      롯데          1     T  40  34    5    6    8  ...   3
# ...

# %%
final=pd.concat([df,DH])

# %%
final1=final.sort_values(by='G_DAY_DS').reset_index().drop('index',axis=1)

# %%
final1
# Out:
#        G_DAY_DS T_ID VS_T_ID  HEADER_NO TB_SC  PA  AB  RBI  RUN  HIT  ...  BB  \
# 0    2020-07-21  KIA      한화          0     T  50  41    9   10   16  ...   8
# 1    2020-07-21   SK      롯데          0     B  40  34    8    8   13  ...   4
# 2    2020-07-21   KT      LG          0     B  39  34   10   10   12  ...   4
# 3    2020-07-21   NC      삼성          0     B  42  38    6    6   13  ...   2
# 4    2020-07-21   두산      키움          0     B  32  31    6    6    7  ...   1
# ..          ...  ...     ...        ...   ...  ..  ..  ...  ...  ...  ...  ..
# 470  2020-09-20   KT      SK          0     T  43  37   10   10   11  ...   4
# 471  2020-09-20   한화     KIA          0     T  50  40   11   11   16  ...   6
# 472  2020-09-20   삼성      키움          0     B  48  42   12   14   18  ...   5
# 473  2020-09-20   SK      KT          0     B  31  28    1    2    3  ...   3
# 474  2020-09-20   롯데      NC          1     B  38  35    1    2    8  ...   3
#
# ...

# %%
final1['G_ID']=final1.index

# %%
final1.replace('한화','HH',inplace=True)
final1.replace('KIA','HT',inplace=True)
final1.replace('두산','OB',inplace=True)
final1.replace('롯데','LT',inplace=True)
final1.replace('hero','WO',inplace=True)
final1.replace('삼성','SS',inplace=True)

# %%
final1.replace('KIA','HT',inplace=True)
final1.replace('두산','OB',inplace=True)
final1.replace('롯데','LT',inplace=True)
final1.replace('hero','WO',inplace=True)
final1.replace('삼성','SS',inplace=True)

# %%
final1
# Out:
#        G_DAY_DS T_ID VS_T_ID  HEADER_NO TB_SC  PA  AB  RBI  RUN  HIT  ...  \
# 0    2020-07-21   HT      HH          0     T  50  41    9   10   16  ...
# 1    2020-07-21   SK      LT          0     B  40  34    8    8   13  ...
# 2    2020-07-21   KT      LG          0     B  39  34   10   10   12  ...
# 3    2020-07-21   NC      SS          0     B  42  38    6    6   13  ...
# 4    2020-07-21   OB      키움          0     B  32  31    6    6    7  ...
# ..          ...  ...     ...        ...   ...  ..  ..  ...  ...  ...  ...
# 470  2020-09-20   KT      SK          0     T  43  37   10   10   11  ...
# 471  2020-09-20   HH      HT          0     T  50  40   11   11   16  ...
# 472  2020-09-20   SS      키움          0     B  48  42   12   14   18  ...
# 473  2020-09-20   SK      KT          0     B  31  28    1    2    3  ...
# 474  2020-09-20   LT      NC          1     B  38  35    1    2    8  ...
#
#       IB  HP  KK  GD  ERR  LOB  P_HRA_RT  P_AB_CN  P_HIT_CN  G_ID
# ...

# %%
cols = final1.columns.tolist()

tmp = cols[27]

del cols[27]

cols.insert(0,tmp) 

final1 = final1[cols]

# %%
final1
# Out:
#      G_ID    G_DAY_DS T_ID VS_T_ID  HEADER_NO TB_SC  PA  AB  RBI  RUN  ...  \
# 0       0  2020-07-21   HT      HH          0     T  50  41    9   10  ...
# 1       1  2020-07-21   SK      LT          0     B  40  34    8    8  ...
# 2       2  2020-07-21   KT      LG          0     B  39  34   10   10  ...
# 3       3  2020-07-21   NC      SS          0     B  42  38    6    6  ...
# 4       4  2020-07-21   OB      키움          0     B  32  31    6    6  ...
# ..    ...         ...  ...     ...        ...   ...  ..  ..  ...  ...  ...
# 470   470  2020-09-20   KT      SK          0     T  43  37   10   10  ...
# 471   471  2020-09-20   HH      HT          0     T  50  40   11   11  ...
# 472   472  2020-09-20   SS      키움          0     B  48  42   12   14  ...
# 473   473  2020-09-20   SK      KT          0     B  31  28    1    2  ...
# 474   474  2020-09-20   LT      NC          1     B  38  35    1    2  ...
#
#      BB   IB  HP  KK  GD  ERR  LOB  P_HRA_RT  P_AB_CN  P_HIT_CN
# ...

# %%
final1.to_csv('team_hitter final.csv')
